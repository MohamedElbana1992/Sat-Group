# %%
import numpy as np
import pandas as pd
import seaborn as sns

# %%
df=pd.read_csv('datasets/sendy_logistics.csv')
df
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 0       Order_No_4211   User_Id_633         Bike              3
# 1      Order_No_25375  User_Id_2285         Bike              3
# 2       Order_No_1899   User_Id_265         Bike              3
# 3       Order_No_9336  User_Id_1402         Bike              3
# 4      Order_No_27883  User_Id_1737         Bike              1
# ...               ...           ...          ...            ...
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 0                 Business                         9
# 1                 Personal                        12
# ...

# %%
df['Temperature(fahrenheit)']=(df['Temperature']*9/5)+(32)
df
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 0       Order_No_4211   User_Id_633         Bike              3
# 1      Order_No_25375  User_Id_2285         Bike              3
# 2       Order_No_1899   User_Id_265         Bike              3
# 3       Order_No_9336  User_Id_1402         Bike              3
# 4      Order_No_27883  User_Id_1737         Bike              1
# ...               ...           ...          ...            ...
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 0                 Business                         9
# 1                 Personal                        12
# ...

# %%
df['Diff Temp']=df['Temperature']-(30)
df
# Out:
#              Order No       User Id Vehicle Type  Platform Type  \
# 0       Order_No_4211   User_Id_633         Bike              3
# 1      Order_No_25375  User_Id_2285         Bike              3
# 2       Order_No_1899   User_Id_265         Bike              3
# 3       Order_No_9336  User_Id_1402         Bike              3
# 4      Order_No_27883  User_Id_1737         Bike              1
# ...               ...           ...          ...            ...
# 21196   Order_No_8834  User_Id_2001         Bike              3
# 21197  Order_No_22892  User_Id_1796         Bike              3
# 21198   Order_No_2831  User_Id_2956         Bike              3
# 21199   Order_No_6174  User_Id_2524         Bike              1
# 21200   Order_No_9836   User_Id_718         Bike              3
#
#       Personal or Business  Placement - Day of Month  \
# 0                 Business                         9
# 1                 Personal                        12
# ...

# %%
sns.kdeplot(x='Temperature(fahrenheit)',data=df)
# Out:
# <AxesSubplot:xlabel='Temperature(fahrenheit)', ylabel='Density'>

# %%
sns.kdeplot(x='Diff Temp',data=df)
# Out:
# <AxesSubplot:xlabel='Diff Temp', ylabel='Density'>

# %%
sns.kdeplot(x='Temperature(fahrenheit)',hue='Personal or Business',data=df)
# Out:
# <AxesSubplot:xlabel='Temperature(fahrenheit)', ylabel='Density'>
